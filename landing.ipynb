# %% [markdown]
# # Hi
# ## Nice to meet you
# ### We got some cool data
# #### To analyse

# %%
import numpy as np # for maths 
import matplotlib # for plotting 
import matplotlib as mpl
import matplotlib.pyplot as plt

import os 

import pandas as pd # pandas is a popular library in industry for manipulating large data tables

# configure notebook for plotting
# %matplotlib inline 
mpl.style.use('seaborn-colorblind') # colourblind-friendly colour scheme

# define default plot settings
matplotlib.rcParams['image.origin'] = 'lower'
matplotlib.rcParams['figure.figsize']=(8.0,6.0)    #(6.0,4.0)
matplotlib.rcParams['font.size']=16              #10 
matplotlib.rcParams['savefig.dpi']= 300             #72 

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# First, let's create one big CSV document for all of our data! Send thoughts and prayers for our storage

# %%
# Path to the directory containing your CSV files

root_dir ='universe_8'
#i = ["Back", "Front", "Top", "Bottom", "Left", "Right"]
# List to store DataFrames from each CSV
dfs = []

# Iterate over each CSV file in the directory
# for filename in os.listdir(root_dir):
#     if filename == "Star_Data.csv":
#         filepath = os.path.join(all_star_directories, filename)
#         # Read the CSV file into a DataFrame and append it to the list
#         dfs.append(pd.read_csv(filepath))

for subdir, dirs, files in os.walk(root_dir):
    for file in files:
        if file == "Star_Data.csv":
            filepath = os.path.join(subdir, file)
            dfs.append(pd.read_csv(filepath))

    

# Concatenate all DataFrames in the list along the rows
combined_df = pd.concat(dfs, ignore_index=True)

# Path to the output CSV file
output_file = 'universe_8/combined_stars.csv'

# Write the combined DataFrame to a new CSV file
combined_df.to_csv(output_file, index=False)

print("Combined CSV file created successfully.")
# Out:
# Combined CSV file created successfully.

# %% [markdown]
# Data: combined, stem: slayed, time: to cri

# %%
star_data = pd.read_csv(root_dir+'/combined_stars.csv') 
#print(stars.keys())

# %%
import re
directions = [re.match(r'([a-zA-Z]+)', view).group() for view in star_data['Name']]

print(directions)
# Out:
# ['BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS', 'BackS'
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

#star_data = pd.read_csv('stars.csv')

# Create a new figure for the 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Define a fixed Z-coordinate for each view
view_z = {'TopS': 10, 'lefts': 20, 'fronts': 30, 'BackS': 40, 'rights': 50, 'bottoms': 60}

# Loop through each view and plot the stars
views = ['TopS', 'LeftS', 'fronts', 'BackS', 'rights', 'bottoms']
colors = ['b', 'g', 'r', 'c', 'm', 'y']  # Color for each view
for i, view in enumerate(directions):
    view_data = star_data[star_data['Name'] == view]
    ax.scatter(view_data['X'], view_data['Y'], view_z[view], c=colors[i], label=view)

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Plot of Stars from Different Views')
ax.legend()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[34], line 20
#      18 for i, view in enumerate(directions):
#      19     view_data = star_data[star_data['Name'] == view]
# ---> 20     ax.scatter(view_data['X'], view_data['Y'], view_z[view], c=colors[i], label=view)
#      22 # Set labels and title
#      23 ax.set_xlabel('X')
#
# IndexError: list index out of range

# %% [markdown]
# there there queen, it doesn't always plot nicely

# %%
import pandas as pd
# load the data
root_dir = "universe_8"
dl_data = pd.read_csv(filepath_or_buffer= root_dir + '/combined_stars.csv')
dl_data.head(5)

temp_data = pd.read_csv(filepath_or_buffer=root_dir + '/Top/Star_Data.csv')

# %%
dl_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55819 entries, 0 to 55818
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            55819 non-null  object
#  1   X               55819 non-null  float64
#  2   Y               55819 non-null  float64
#  3   BlueF           55819 non-null  float64
#  4   GreenF          55819 non-null  float64
#  5   RedF            55819 non-null  float64
#  6   Parallax        55819 non-null  float64
#  7   RadialVelocity  55819 non-null  float64
#  8   Variable?       55819 non-null  int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 3.8+ MB

# %%
print(dl_data["X"])
# Out:
# 0        32.1967
# 1        32.1590
# 2        32.1582
# 3        32.1994
# 4        32.1127
#           ...
# 55814   -15.6029
# 55815   -10.4146
# 55816   -14.6272
# 55817    -2.9193
# 55818    37.8301
# Name: X, Length: 55819, dtype: float64

# %%
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import minmax_scale

#data_to_cluster = dl_data.loc[dl_data["X"], dl_data["Y"]]
sns.pairplot(temp_data)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[14], line 6
#       3 from sklearn.preprocessing import minmax_scale
#       5 #data_to_cluster = dl_data.loc[dl_data["X"], dl_data["Y"]]
# ----> 6 sns.pairplot(temp_data)
#
# File c:\Users\neha\anaconda3\lib\site-packages\seaborn\axisgrid.py:2144, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2142 diag_kws.setdefault("legend", False)
#    2143 if diag_kind == "hist":
# -> 2144     grid.map_diag(histplot, **diag_kws)
#    2145 elif diag_kind == "kde":
#    2146     diag_kws.setdefault("fill", True)
#
# File c:\Users\neha\anaconda3\lib\site-packages\seaborn\axisgrid.py:1507, in PairGrid.map_diag(self, func, **kwargs)
#    1505     plot_kwargs.setdefault("hue_order", self._hue_order)
# ...

# %%
k_means = KMeans(n_clusters=2)

# fit and transform k_means object to scaled data
k_means.fit_transform(temp_data["X"])
sns.scatterplot(data=temp_data, hue="cluster_labels")
plt.title("test")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 4
#       1 k_means = KMeans(n_clusters=2)
#       3 # fit and transform k_means object to scaled data
# ----> 4 k_means.fit_transform(temp_data["X"])
#       5 sns.scatterplot(data=temp_data, hue="cluster_labels")
#       6 plt.title("test")
#
# File c:\Users\neha\anaconda3\lib\site-packages\sklearn\utils\_set_output.py:142, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     140 @wraps(f)
#     141 def wrapped(self, X, *args, **kwargs):
# --> 142     data_to_wrap = f(self, X, *args, **kwargs)
#     143     if isinstance(data_to_wrap, tuple):
#     144         # only wrap the first output for cross decomposition
#     145         return (
#     146             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     147             *data_to_wrap[1:],
#     148         )
#
# ...
